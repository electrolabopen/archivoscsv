# %% [markdown]
# <a href="https://colab.research.google.com/github/electrolabopen/archivoscsv/blob/master/detectarviolenciayolo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !git clone https://github.com/TheAnkurGoswami/Human-Violence-Detection
# Out:
# Cloning into 'Human-Violence-Detection'...
# remote: Enumerating objects: 82, done.
# remote: Counting objects: 100% (82/82), done.
# remote: Compressing objects: 100% (78/78), done.
# remote: Total 82 (delta 21), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (82/82), done.

# %%
# !pip install -r /content/Human-Violence-Detection/requirements.txt

# %%
# !pip install tensorflow==1.15

# %%
# %cp /content/gdrive/MyDrive/yoloviolence/openpose.h5 /content/Human-Violence-Detection/models

# %%
# %cp /content/gdrive/MyDrive/yoloviolence/yolo.h5 /content/Human-Violence-Detection/models

# %%
# %cd /content/Human-Violence-Detection
# Out:
# /content/Human-Violence-Detection

# %%
# !python /content/Human-Violence-Detection/main.py
# Out:
# Using TensorFlow backend.
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/backend/tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/backend/tensorflow_backend.py:181: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/backend/tensorflow_backend.py:186: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# 2021-02-25 04:15:28.998234: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2021-02-25 04:15:29.000850: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2199995000 Hz
# ...

# %%
# !pip install tensorflow==1.14

# %%
# !pip install configobj

# %%
# !pip install keras==2.2.4
